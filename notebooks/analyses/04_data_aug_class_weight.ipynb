# %% [markdown]
# <a href="https://colab.research.google.com/github/amartinsmg/classification-of-medical-images-using-cnn/blob/main/notebooks/analyses/04_data_aug_class_weight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/amartinsmg/classification-of-medical-images-using-cnn.git
# %cd /content/classification-of-medical-images-using-cnn
# Out:
# /content
# Cloning into 'classification-of-medical-images-using-cnn'...
# remote: Enumerating objects: 1152, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 1152 (delta 47), reused 100 (delta 33), pack-reused 1023 (from 1)
# Receiving objects: 100% (1152/1152), 9.90 MiB | 21.16 MiB/s, done.
# Resolving deltas: 100% (565/565), done.
# /content/classification-of-medical-images-using-cnn

# %%
from google.colab import drive

drive.mount("/content/drive")

BASE_PATH = "/content/drive/MyDrive/classification-of-medical-images-using-cnn/"
# Out:
# Mounted at /content/drive

# %%
experiment_names = ["efficientnet-baseline", "efficientnet-no-data-aug", "efficientnet-class-weight", "efficientnet-data-aug-class-weight",
                  "densenet-baseline", "densenet-no-data-aug", "densenet-class-weight", "densenet-data-aug-class-weight",
                  "resnet-baseline", "resnet-no-data-aug", "resnet-class-weight", "resnet-data-aug-class-weight"]
COMPARISON_PATH = "comparisons/04-data-aug-class-weight"
RESULT_PATH = BASE_PATH + "results"
SAVE_DIR = BASE_PATH + COMPARISON_PATH

# %%
from src.analyses import load_experiments

experiments = load_experiments(RESULT_PATH, experiment_names)

# %%
from src.analyses import metrics_table
from IPython.display import display

metrics = metrics_table(experiments)
display(metrics)
# Out:
#                                     accuracy-mean  accuracy-std  \
# experiment
# efficientnet-baseline                    0.866987      0.022664
# efficientnet-no-data-aug                 0.796474      0.030095
# efficientnet-class-weight                0.845085      0.004206
# efficientnet-data-aug-class-weight       0.880876      0.011281
# densenet-baseline                        0.855769      0.019275
# densenet-no-data-aug                     0.819979      0.056270
# densenet-class-weight                    0.844017      0.042042
# densenet-data-aug-class-weight           0.880876      0.009994
# resnet-baseline                          0.879808      0.024234
# resnet-no-data-aug                       0.808226      0.018704
# resnet-class-weight                      0.831197      0.053908
# resnet-data-aug-class-weight             0.889423      0.012619
#
#                                     precision-mean  precision-std  \
# experiment
# efficientnet-baseline                     0.848382       0.044925
# efficientnet-no-data-aug                  0.756865       0.028928
# efficientnet-class-weight                 0.806926       0.006896
# efficientnet-data-aug-class-weight        0.879516       0.044861
# densenet-baseline                         0.831175       0.031108
# densenet-no-data-aug                      0.788886       0.064417
# densenet-class-weight                     0.823509       0.069227
# densenet-data-aug-class-weight            0.869720       0.025490
# resnet-baseline                           0.885167       0.056200
# resnet-no-data-aug                        0.768948       0.019748
# resnet-class-weight                       0.818086       0.086537
# resnet-data-aug-class-weight              0.914868       0.030792
#
#                                     recall-mean  recall-std  f1-score-mean  \
# experiment
# efficientnet-baseline                  0.964103    0.025726       0.901138
# efficientnet-no-data-aug               0.996581    0.003198       0.859976
# efficientnet-class-weight              0.988889    0.004835       0.888649
# efficientnet-data-aug-class-weight     0.943590    0.039943       0.908458
# densenet-baseline                      0.968376    0.017433       0.893862
# densenet-no-data-aug                   0.985470    0.015432       0.874262
# densenet-class-weight                  0.969231    0.032636       0.887430
# densenet-data-aug-class-weight         0.953846    0.018842       0.909299
# resnet-baseline                        0.936752    0.042306       0.907570
# resnet-no-data-aug                     0.992308    0.004187       0.866276
# resnet-class-weight                    0.961538    0.042028       0.879198
# resnet-data-aug-class-weight           0.910256    0.041239       0.911215
#
#                                     f1-score-std  specificity-mean  \
# experiment
# efficientnet-baseline                   0.013308          0.705128
# efficientnet-no-data-aug                0.017490          0.462963
# efficientnet-class-weight               0.002221          0.605413
# efficientnet-data-aug-class-weight      0.004914          0.776353
# densenet-baseline                       0.010904          0.668091
# densenet-no-data-aug                    0.033387          0.544160
# densenet-class-weight                   0.024917          0.635328
# densenet-data-aug-class-weight          0.005391          0.759259
# resnet-baseline                         0.013514          0.784900
# resnet-no-data-aug                      0.010908          0.501425
# resnet-class-weight                     0.030881          0.613960
# resnet-data-aug-class-weight            0.011472          0.854701
#
#                                     specificity-std  auc-roc-mean  auc-roc-std
# experiment
# efficientnet-baseline                      0.102979      0.961047     0.002615
# efficientnet-no-data-aug                   0.085494      0.968920     0.002772
# efficientnet-class-weight                  0.019218      0.969958     0.001839
# efficientnet-data-aug-class-weight         0.094941      0.961739     0.000533
# densenet-baseline                          0.080355      0.956991     0.001435
# densenet-no-data-aug                       0.174756      0.962950     0.003478
# densenet-class-weight                      0.165745      0.960771     0.003623
# densenet-data-aug-class-weight             0.057793      0.956323     0.000575
# resnet-baseline                            0.129684      0.954208     0.005962
# resnet-no-data-aug                         0.056730      0.963535     0.003811
# resnet-class-weight                        0.211681      0.960545     0.005001
# resnet-data-aug-class-weight               0.062904      0.956834     0.003682

# %%
from src.analyses import full_comparison
import matplotlib.pyplot as plt

resnet_exps = [exp for exp in experiment_names if exp.startswith("resnet")]

_ = full_comparison(
  base_result_dir=RESULT_PATH,
  experiment_names=resnet_exps,
  show_plot=True,
  save_dir=SAVE_DIR,
)
# Out:
# Results saved in /content/drive/MyDrive/classification-of-medical-images-using-cnn/comparisons/04-data-aug-class-weight
#                               accuracy-mean  accuracy-std  precision-mean  \
# experiment
# resnet-baseline                    0.879808      0.024234        0.885167
# resnet-no-data-aug                 0.808226      0.018704        0.768948
# resnet-class-weight                0.831197      0.053908        0.818086
# resnet-data-aug-class-weight       0.889423      0.012619        0.914868
#
#                               precision-std  recall-mean  recall-std  \
# experiment
# resnet-baseline                    0.056200     0.936752    0.042306
# resnet-no-data-aug                 0.019748     0.992308    0.004187
# resnet-class-weight                0.086537     0.961538    0.042028
# resnet-data-aug-class-weight       0.030792     0.910256    0.041239
#
#                               f1-score-mean  f1-score-std  specificity-mean  \
# experiment
# resnet-baseline                    0.907570      0.013514          0.784900
# resnet-no-data-aug                 0.866276      0.010908          0.501425
# resnet-class-weight                0.879198      0.030881          0.613960
# resnet-data-aug-class-weight       0.911215      0.011472          0.854701
#
#                               specificity-std  auc-roc-mean  auc-roc-std
# experiment
# resnet-baseline                      0.129684      0.954208     0.005962
# resnet-no-data-aug                   0.056730      0.963535     0.003811
# resnet-class-weight                  0.211681      0.960545     0.005001
# resnet-data-aug-class-weight         0.062904      0.956834     0.003682

# %%
densenet_exps = [exp for exp in experiment_names if exp.startswith("densenet")]

_ = full_comparison(
  base_result_dir=RESULT_PATH,
  experiment_names=densenet_exps,
  show_plot=True,
  save_dir=SAVE_DIR
)
# Out:
# Results saved in /content/drive/MyDrive/classification-of-medical-images-using-cnn/comparisons/04-data-aug-class-weight
#                                 accuracy-mean  accuracy-std  precision-mean  \
# experiment
# densenet-baseline                    0.855769      0.019275        0.831175
# densenet-no-data-aug                 0.819979      0.056270        0.788886
# densenet-class-weight                0.844017      0.042042        0.823509
# densenet-data-aug-class-weight       0.880876      0.009994        0.869720
#
#                                 precision-std  recall-mean  recall-std  \
# experiment
# densenet-baseline                    0.031108     0.968376    0.017433
# densenet-no-data-aug                 0.064417     0.985470    0.015432
# densenet-class-weight                0.069227     0.969231    0.032636
# densenet-data-aug-class-weight       0.025490     0.953846    0.018842
#
#                                 f1-score-mean  f1-score-std  specificity-mean  \
# experiment
# densenet-baseline                    0.893862      0.010904          0.668091
# densenet-no-data-aug                 0.874262      0.033387          0.544160
# densenet-class-weight                0.887430      0.024917          0.635328
# densenet-data-aug-class-weight       0.909299      0.005391          0.759259
#
#                                 specificity-std  auc-roc-mean  auc-roc-std
# experiment
# densenet-baseline                      0.080355      0.956991     0.001435
# densenet-no-data-aug                   0.174756      0.962950     0.003478
# densenet-class-weight                  0.165745      0.960771     0.003623
# densenet-data-aug-class-weight         0.057793      0.956323     0.000575

# %%
efficientnet_exps = [exp for exp in experiment_names if exp.startswith("efficientnet")]

_ = full_comparison(
  base_result_dir=RESULT_PATH,
  experiment_names=efficientnet_exps,
  show_plot=True,
  save_dir=SAVE_DIR,
)
# Out:
# Results saved in /content/drive/MyDrive/classification-of-medical-images-using-cnn/comparisons/04-data-aug-class-weight
#                                     accuracy-mean  accuracy-std  \
# experiment
# efficientnet-baseline                    0.866987      0.022664
# efficientnet-no-data-aug                 0.796474      0.030095
# efficientnet-class-weight                0.845085      0.004206
# efficientnet-data-aug-class-weight       0.880876      0.011281
#
#                                     precision-mean  precision-std  \
# experiment
# efficientnet-baseline                     0.848382       0.044925
# efficientnet-no-data-aug                  0.756865       0.028928
# efficientnet-class-weight                 0.806926       0.006896
# efficientnet-data-aug-class-weight        0.879516       0.044861
#
#                                     recall-mean  recall-std  f1-score-mean  \
# experiment
# efficientnet-baseline                  0.964103    0.025726       0.901138
# efficientnet-no-data-aug               0.996581    0.003198       0.859976
# efficientnet-class-weight              0.988889    0.004835       0.888649
# efficientnet-data-aug-class-weight     0.943590    0.039943       0.908458
#
#                                     f1-score-std  specificity-mean  \
# experiment
# efficientnet-baseline                   0.013308          0.705128
# efficientnet-no-data-aug                0.017490          0.462963
# efficientnet-class-weight               0.002221          0.605413
# efficientnet-data-aug-class-weight      0.004914          0.776353
#
#                                     specificity-std  auc-roc-mean  auc-roc-std
# experiment
# efficientnet-baseline                      0.102979      0.961047     0.002615
# efficientnet-no-data-aug                   0.085494      0.968920     0.002772
# efficientnet-class-weight                  0.019218      0.969958     0.001839
# efficientnet-data-aug-class-weight         0.094941      0.961739     0.000533

# %%
from src.analyses import full_comparison

_ = full_comparison(
  base_result_dir=RESULT_PATH,
  experiment_names=experiment_names,
  show_plot=False,
  save_dir=SAVE_DIR,
  separe_archs=True
)
# Out:
# Results saved in /content/drive/MyDrive/classification-of-medical-images-using-cnn/comparisons/04-data-aug-class-weight

# %% [markdown]
# Faz upload da tabela e dos gráficos das comparações para o DagsHub

# %%
# %pip install -q dvc dagshub

import dagshub
from google.colab import userdata

dagshub.auth.add_app_token(token=userdata.get("DAGSHUB_TOKEN"))


dagshub.upload_files(
    "amartinsmg/classification-of-medical-images-using-cnn",
    local_path=SAVE_DIR,
    remote_path=COMPARISON_PATH,
)
