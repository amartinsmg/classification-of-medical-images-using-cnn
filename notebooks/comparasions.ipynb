# %%
# %cd /content
# !git clone https://github.com/amartinsmg/classification-of-medical-images-using-cnn.git
# %cd /content/classification-of-medical-images-using-cnn
# Out:
# /content
# Cloning into 'classification-of-medical-images-using-cnn'...
# remote: Enumerating objects: 776, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 776 (delta 76), reused 131 (delta 58), pack-reused 612 (from 1)
# Receiving objects: 100% (776/776), 7.57 MiB | 19.98 MiB/s, done.
# Resolving deltas: 100% (402/402), done.
# /content/classification-of-medical-images-using-cnn

# %%
from google.colab import drive

drive.mount("/content/drive")

BASE_PATH = "/content/drive/MyDrive/classification-of-medical-images-using-cnn/"
# Out:
# Mounted at /content/drive

# %%
from src.db import get_engine

DB_PATH = f"sqlite:///{BASE_PATH}/experiments.db"

engine = get_engine(DB_PATH)

# %%
import sqlalchemy

QUERY = sqlalchemy.text("SELECT * FROM v_experiment_summary")

# %%
import pandas as pd

with engine.connect() as con:
    df = pd.read_sql(QUERY, con=con)

# %%
from IPython.display import display

display(df.style.hide(axis="index"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_5f97d" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_5f97d_level0_col0" class="col_heading level0 col0" >experiment</th>
#       <th id="T_5f97d_level0_col1" class="col_heading level0 col1" >n_runs</th>
#       <th id="T_5f97d_level0_col2" class="col_heading level0 col2" >accuracy_mean</th>
#       <th id="T_5f97d_level0_col3" class="col_heading level0 col3" >accuracy_std</th>
#       <th id="T_5f97d_level0_col4" class="col_heading level0 col4" >precision_mean</th>
#       <th id="T_5f97d_level0_col5" class="col_heading level0 col5" >precision_std</th>
#       <th id="T_5f97d_level0_col6" class="col_heading level0 col6" >recall_mean</th>
#       <th id="T_5f97d_level0_col7" class="col_heading level0 col7" >recall_std</th>
#       <th id="T_5f97d_level0_col8" class="col_heading level0 col8" >f1_mean</th>
#       <th id="T_5f97d_level0_col9" class="col_heading level0 col9" >f1_std</th>
#       <th id="T_5f97d_level0_col10" class="col_heading level0 col10" >specificity_mean</th>
#       <th id="T_5f97d_level0_col11" class="col_heading level0 col11" >specificity_std</th>
#       <th id="T_5f97d_level0_col12" class="col_heading level0 col12" >auc_roc_mean</th>
#       <th id="T_5f97d_level0_col13" class="col_heading level0 col13" >auc_roc_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5f97d_row0_col0" class="data row0 col0" >densenet-baseline</td>
#       <td id="T_5f97d_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_5f97d_row0_col2" class="data row0 col2" >0.855800</td>
#       <td id="T_5f97d_row0_col3" class="data row0 col3" >0.019300</td>
#       <td id="T_5f97d_row0_col4" class="data row0 col4" >0.831200</td>
#       <td id="T_5f97d_row0_col5" class="data row0 col5" >0.031100</td>
#       <td id="T_5f97d_row0_col6" class="data row0 col6" >0.968400</td>
#       <td id="T_5f97d_row0_col7" class="data row0 col7" >0.017400</td>
#       <td id="T_5f97d_row0_col8" class="data row0 col8" >0.893900</td>
#       <td id="T_5f97d_row0_col9" class="data row0 col9" >0.010900</td>
#       <td id="T_5f97d_row0_col10" class="data row0 col10" >0.668100</td>
#       <td id="T_5f97d_row0_col11" class="data row0 col11" >0.080400</td>
#       <td id="T_5f97d_row0_col12" class="data row0 col12" >0.957000</td>
#       <td id="T_5f97d_row0_col13" class="data row0 col13" >0.001400</td>
#     </tr>
#     <tr>
#       <td id="T_5f97d_row1_col0" class="data row1 col0" >efficientnet-baseline</td>
#       <td id="T_5f97d_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_5f97d_row1_col2" class="data row1 col2" >0.867000</td>
#       <td id="T_5f97d_row1_col3" class="data row1 col3" >0.022700</td>
#       <td id="T_5f97d_row1_col4" class="data row1 col4" >0.848400</td>
#       <td id="T_5f97d_row1_col5" class="data row1 col5" >0.044900</td>
#       <td id="T_5f97d_row1_col6" class="data row1 col6" >0.964100</td>
#       <td id="T_5f97d_row1_col7" class="data row1 col7" >0.025700</td>
#       <td id="T_5f97d_row1_col8" class="data row1 col8" >0.901100</td>
#       <td id="T_5f97d_row1_col9" class="data row1 col9" >0.013300</td>
#       <td id="T_5f97d_row1_col10" class="data row1 col10" >0.705100</td>
#       <td id="T_5f97d_row1_col11" class="data row1 col11" >0.103000</td>
#       <td id="T_5f97d_row1_col12" class="data row1 col12" >0.961000</td>
#       <td id="T_5f97d_row1_col13" class="data row1 col13" >0.002600</td>
#     </tr>
#     <tr>
#       <td id="T_5f97d_row2_col0" class="data row2 col0" >resnet-baseline</td>
#       <td id="T_5f97d_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_5f97d_row2_col2" class="data row2 col2" >0.879800</td>
#       <td id="T_5f97d_row2_col3" class="data row2 col3" >0.024200</td>
#       <td id="T_5f97d_row2_col4" class="data row2 col4" >0.885200</td>
#       <td id="T_5f97d_row2_col5" class="data row2 col5" >0.056200</td>
#       <td id="T_5f97d_row2_col6" class="data row2 col6" >0.936800</td>
#       <td id="T_5f97d_row2_col7" class="data row2 col7" >0.042300</td>
#       <td id="T_5f97d_row2_col8" class="data row2 col8" >0.907600</td>
#       <td id="T_5f97d_row2_col9" class="data row2 col9" >0.013500</td>
#       <td id="T_5f97d_row2_col10" class="data row2 col10" >0.784900</td>
#       <td id="T_5f97d_row2_col11" class="data row2 col11" >0.129700</td>
#       <td id="T_5f97d_row2_col12" class="data row2 col12" >0.954200</td>
#       <td id="T_5f97d_row2_col13" class="data row2 col13" >0.006000</td>
#     </tr>
#   </tbody>
# </table>
