# %%
# %cd /content
# !git clone https://github.com/amartinsmg/classification-of-medical-images-using-cnn.git
# %cd /content/classification-of-medical-images-using-cnn
# Out:
# /content
# Cloning into 'classification-of-medical-images-using-cnn'...
# remote: Enumerating objects: 964, done.
# remote: Counting objects: 100% (352/352), done.
# remote: Compressing objects: 100% (240/240), done.
# remote: Total 964 (delta 152), reused 281 (delta 107), pack-reused 612 (from 1)
# Receiving objects: 100% (964/964), 8.30 MiB | 20.78 MiB/s, done.
# Resolving deltas: 100% (478/478), done.
# /content/classification-of-medical-images-using-cnn

# %%
from google.colab import drive

drive.mount("/content/drive")

BASE_PATH = "/content/drive/MyDrive/classification-of-medical-images-using-cnn/"
# Out:
# Mounted at /content/drive

# %%
from src.db import get_engine

DB_PATH = f"sqlite:///{BASE_PATH}/experiments.db"

engine = get_engine(DB_PATH)

# %%
import sqlalchemy

QUERY = sqlalchemy.text("SELECT * FROM v_experiment_summary")

# %%
import pandas as pd

with engine.connect() as con:
    df = pd.read_sql(QUERY, con=con)

# %%
from IPython.display import display

display(df.style.hide(axis="index"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_f6c11" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_f6c11_level0_col0" class="col_heading level0 col0" >experiment</th>
#       <th id="T_f6c11_level0_col1" class="col_heading level0 col1" >n_runs</th>
#       <th id="T_f6c11_level0_col2" class="col_heading level0 col2" >accuracy_mean</th>
#       <th id="T_f6c11_level0_col3" class="col_heading level0 col3" >accuracy_std</th>
#       <th id="T_f6c11_level0_col4" class="col_heading level0 col4" >precision_mean</th>
#       <th id="T_f6c11_level0_col5" class="col_heading level0 col5" >precision_std</th>
#       <th id="T_f6c11_level0_col6" class="col_heading level0 col6" >recall_mean</th>
#       <th id="T_f6c11_level0_col7" class="col_heading level0 col7" >recall_std</th>
#       <th id="T_f6c11_level0_col8" class="col_heading level0 col8" >f1_mean</th>
#       <th id="T_f6c11_level0_col9" class="col_heading level0 col9" >f1_std</th>
#       <th id="T_f6c11_level0_col10" class="col_heading level0 col10" >specificity_mean</th>
#       <th id="T_f6c11_level0_col11" class="col_heading level0 col11" >specificity_std</th>
#       <th id="T_f6c11_level0_col12" class="col_heading level0 col12" >auc_roc_mean</th>
#       <th id="T_f6c11_level0_col13" class="col_heading level0 col13" >auc_roc_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f6c11_row0_col0" class="data row0 col0" >densenet-baseline</td>
#       <td id="T_f6c11_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_f6c11_row0_col2" class="data row0 col2" >0.855800</td>
#       <td id="T_f6c11_row0_col3" class="data row0 col3" >0.019300</td>
#       <td id="T_f6c11_row0_col4" class="data row0 col4" >0.831200</td>
#       <td id="T_f6c11_row0_col5" class="data row0 col5" >0.031100</td>
#       <td id="T_f6c11_row0_col6" class="data row0 col6" >0.968400</td>
#       <td id="T_f6c11_row0_col7" class="data row0 col7" >0.017400</td>
#       <td id="T_f6c11_row0_col8" class="data row0 col8" >0.893900</td>
#       <td id="T_f6c11_row0_col9" class="data row0 col9" >0.010900</td>
#       <td id="T_f6c11_row0_col10" class="data row0 col10" >0.668100</td>
#       <td id="T_f6c11_row0_col11" class="data row0 col11" >0.080400</td>
#       <td id="T_f6c11_row0_col12" class="data row0 col12" >0.957000</td>
#       <td id="T_f6c11_row0_col13" class="data row0 col13" >0.001400</td>
#     </tr>
#     <tr>
#       <td id="T_f6c11_row1_col0" class="data row1 col0" >densenet-no-data-aug</td>
#       <td id="T_f6c11_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_f6c11_row1_col2" class="data row1 col2" >0.854200</td>
#       <td id="T_f6c11_row1_col3" class="data row1 col3" >0.035300</td>
#       <td id="T_f6c11_row1_col4" class="data row1 col4" >0.825500</td>
#       <td id="T_f6c11_row1_col5" class="data row1 col5" >0.046900</td>
#       <td id="T_f6c11_row1_col6" class="data row1 col6" >0.978200</td>
#       <td id="T_f6c11_row1_col7" class="data row1 col7" >0.014100</td>
#       <td id="T_f6c11_row1_col8" class="data row1 col8" >0.894300</td>
#       <td id="T_f6c11_row1_col9" class="data row1 col9" >0.021700</td>
#       <td id="T_f6c11_row1_col10" class="data row1 col10" >0.647400</td>
#       <td id="T_f6c11_row1_col11" class="data row1 col11" >0.117500</td>
#       <td id="T_f6c11_row1_col12" class="data row1 col12" >0.960700</td>
#       <td id="T_f6c11_row1_col13" class="data row1 col13" >0.001600</td>
#     </tr>
#     <tr>
#       <td id="T_f6c11_row2_col0" class="data row2 col0" >densenet-rescaling</td>
#       <td id="T_f6c11_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_f6c11_row2_col2" class="data row2 col2" >0.868600</td>
#       <td id="T_f6c11_row2_col3" class="data row2 col3" >0.008200</td>
#       <td id="T_f6c11_row2_col4" class="data row2 col4" >0.854200</td>
#       <td id="T_f6c11_row2_col5" class="data row2 col5" >0.021000</td>
#       <td id="T_f6c11_row2_col6" class="data row2 col6" >0.953800</td>
#       <td id="T_f6c11_row2_col7" class="data row2 col7" >0.025500</td>
#       <td id="T_f6c11_row2_col8" class="data row2 col8" >0.900700</td>
#       <td id="T_f6c11_row2_col9" class="data row2 col9" >0.005500</td>
#       <td id="T_f6c11_row2_col10" class="data row2 col10" >0.726500</td>
#       <td id="T_f6c11_row2_col11" class="data row2 col11" >0.051400</td>
#       <td id="T_f6c11_row2_col12" class="data row2 col12" >0.941200</td>
#       <td id="T_f6c11_row2_col13" class="data row2 col13" >0.005200</td>
#     </tr>
#     <tr>
#       <td id="T_f6c11_row3_col0" class="data row3 col0" >efficientnet-baseline</td>
#       <td id="T_f6c11_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_f6c11_row3_col2" class="data row3 col2" >0.867000</td>
#       <td id="T_f6c11_row3_col3" class="data row3 col3" >0.022700</td>
#       <td id="T_f6c11_row3_col4" class="data row3 col4" >0.848400</td>
#       <td id="T_f6c11_row3_col5" class="data row3 col5" >0.044900</td>
#       <td id="T_f6c11_row3_col6" class="data row3 col6" >0.964100</td>
#       <td id="T_f6c11_row3_col7" class="data row3 col7" >0.025700</td>
#       <td id="T_f6c11_row3_col8" class="data row3 col8" >0.901100</td>
#       <td id="T_f6c11_row3_col9" class="data row3 col9" >0.013300</td>
#       <td id="T_f6c11_row3_col10" class="data row3 col10" >0.705100</td>
#       <td id="T_f6c11_row3_col11" class="data row3 col11" >0.103000</td>
#       <td id="T_f6c11_row3_col12" class="data row3 col12" >0.961000</td>
#       <td id="T_f6c11_row3_col13" class="data row3 col13" >0.002600</td>
#     </tr>
#     <tr>
#       <td id="T_f6c11_row4_col0" class="data row4 col0" >efficientnet-no-data-aug</td>
#       <td id="T_f6c11_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_f6c11_row4_col2" class="data row4 col2" >0.796500</td>
#       <td id="T_f6c11_row4_col3" class="data row4 col3" >0.030100</td>
#       <td id="T_f6c11_row4_col4" class="data row4 col4" >0.756900</td>
#       <td id="T_f6c11_row4_col5" class="data row4 col5" >0.028900</td>
#       <td id="T_f6c11_row4_col6" class="data row4 col6" >0.996600</td>
#       <td id="T_f6c11_row4_col7" class="data row4 col7" >0.003200</td>
#       <td id="T_f6c11_row4_col8" class="data row4 col8" >0.860000</td>
#       <td id="T_f6c11_row4_col9" class="data row4 col9" >0.017500</td>
#       <td id="T_f6c11_row4_col10" class="data row4 col10" >0.463000</td>
#       <td id="T_f6c11_row4_col11" class="data row4 col11" >0.085500</td>
#       <td id="T_f6c11_row4_col12" class="data row4 col12" >0.968900</td>
#       <td id="T_f6c11_row4_col13" class="data row4 col13" >0.002800</td>
#     </tr>
#     <tr>
#       <td id="T_f6c11_row5_col0" class="data row5 col0" >efficientnet-rescaling</td>
#       <td id="T_f6c11_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_f6c11_row5_col2" class="data row5 col2" >0.625000</td>
#       <td id="T_f6c11_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_f6c11_row5_col4" class="data row5 col4" >0.625000</td>
#       <td id="T_f6c11_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_f6c11_row5_col6" class="data row5 col6" >1.000000</td>
#       <td id="T_f6c11_row5_col7" class="data row5 col7" >0.000000</td>
#       <td id="T_f6c11_row5_col8" class="data row5 col8" >0.769200</td>
#       <td id="T_f6c11_row5_col9" class="data row5 col9" >0.000000</td>
#       <td id="T_f6c11_row5_col10" class="data row5 col10" >0.000000</td>
#       <td id="T_f6c11_row5_col11" class="data row5 col11" >0.000000</td>
#       <td id="T_f6c11_row5_col12" class="data row5 col12" >0.731600</td>
#       <td id="T_f6c11_row5_col13" class="data row5 col13" >0.008900</td>
#     </tr>
#     <tr>
#       <td id="T_f6c11_row6_col0" class="data row6 col0" >resnet-baseline</td>
#       <td id="T_f6c11_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_f6c11_row6_col2" class="data row6 col2" >0.879800</td>
#       <td id="T_f6c11_row6_col3" class="data row6 col3" >0.024200</td>
#       <td id="T_f6c11_row6_col4" class="data row6 col4" >0.885200</td>
#       <td id="T_f6c11_row6_col5" class="data row6 col5" >0.056200</td>
#       <td id="T_f6c11_row6_col6" class="data row6 col6" >0.936800</td>
#       <td id="
